# %% [markdown]
# # Implementing KMeans algorithm
#
# In this exercise, we're trying to code the kmean algorithm ourselves.
#
# Please complete the code in [kmeans_exercise.py](kmeans_exercise.py).
#
# You can use this notebook to test your code.

# %%
import numpy as np
import pandas as pd
from kmeans_exercise import KMeans
import seaborn
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Create some test data.

# %%
n, r = 100, .1
X = pd.DataFrame()
centroids = [[.2, .2], [.8, .2], [.5, .8]]
# centroids = [[.2, .2], [.5, .5], [.8, .8]]
for centroid in centroids:
    X = X.append(pd.DataFrame(dict(
        x1=centroid[0] + r * np.random.randn(n),
        x2=centroid[1] + r * np.random.randn(n))), ignore_index=True)
X = pd.DataFrame(X)

# %%
def draw_clusters(X, centroids=None, labels=None):
    """Plot data, including clusters if provided"""
    plt.figure(figsize=(5,5))
    if centroids is not None:
        f = plt.plot(centroids.T[0], centroids.T[1], '*r', markersize=15)
    if labels is not None:
        colors = list("rbgkw")  # seaborn.color_palette()
        for label in np.unique(labels):
            A = X.values[labels == label, :]
            f = plt.scatter(A[:, 0], A[:, 1], alpha=.4, c=colors.pop())
    else:
        f = plt.scatter(X.x1, X.x2, alpha=.4)

# %%
draw_clusters(X)

# %% [markdown]
# #### Complete your code so that the following code works.

# %%
model = KMeans(k=3)
model.fit(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4dfd5224aec5> in <module>()
#       1 model = KMeans(k=3)
# ----> 2 model.fit(X)
#
# C:\Users\Gustavo\Dropbox\CS6923 - ML - Fall16\Fall 2016\src\NyuPoly-CS6923-Fall16\Lesson 10 - Clustering\kmeans_exercise.py in fit(self, X, max_iter)
#      45         best_score = np.inf
#      46         self.history = [dict(score=None, labels=None, centroids=centroids)]
# ---> 47         for y in range(max_iter):
#      48             pass  # your code here...
#      49             # labels, score = self._compute_labels_and_score(X, centroids)
#
# NameError: name 'xrange' is not defined

# %%
draw_clusters(X, model.centroids, model.predict(X))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-39c4d86b8bc2> in <module>()
# ----> 1 draw_clusters(X, model.centroids, model.predict(X))
#
# AttributeError: 'KMeans' object has no attribute 'centroids'

# %%
model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-afba68787ed8> in <module>()
# ----> 1 model.predict(X)
#
# C:\Users\Gustavo\Dropbox\CS6923 - ML - Fall16\Fall 2016\src\NyuPoly-CS6923-Fall16\Lesson 10 - Clustering\kmeans_exercise.py in predict(self, X)
#      71     def predict(self, X):
#      72         """Predict which to which clusters the data in X belongs"""
# ---> 73         return self._compute_labels_and_score(X, self.centroids)[0]
#      74
#      75     def score(self, X):
#
# AttributeError: 'KMeans' object has no attribute 'centroids'

# %%
model.score(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-234dab8b16bc> in <module>()
# ----> 1 model.score(X)
#
# C:\Users\Gustavo\Dropbox\CS6923 - ML - Fall16\Fall 2016\src\NyuPoly-CS6923-Fall16\Lesson 10 - Clustering\kmeans_exercise.py in score(self, X)
#      75     def score(self, X):
#      76         """Average distance to nearest cluster. Negative value, so that higher is better."""
# ---> 77         return -self._compute_labels_and_score(X, self.centroids)[1]
#
# AttributeError: 'KMeans' object has no attribute 'centroids'

# %% [markdown]
# You could compare your algorithm with `sklearn`'s `KMeans` from `sklearn.cluster`.
